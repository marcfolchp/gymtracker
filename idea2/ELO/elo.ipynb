# %%
import pandas as pd
from pymongo import MongoClient

connection_string = "mongodb+srv://marcfolchpomares:AstonMartin1@mycluster.e19nlo1.mongodb.net/?retryWrites=true&w=majority"

# Connect to MongoDB Atlas
client = MongoClient(connection_string)

# Access a specific database (replace 'your_database' with your actual database name)
db = client.ELO_gym

# Access a specific collection within the database (replace 'your_collection' with your actual collection name)
collection1 = db.objectives

cursor = collection1.find({})
data = list(cursor)

# Create a DataFrame from the retrieved data
objectives = pd.DataFrame(data)

# %%
objectives
# Out:
#                          _id   Bodypart                  Exercise  \
# 0   65bad0143ac0386d0cf7079b      Chest               Bench Press
# 1   65bad0143ac0386d0cf7079c      Chest      Inclined Bench Press
# 2   65bad0143ac0386d0cf7079d      Chest      Declined Bench Press
# 3   65bad0143ac0386d0cf7079e    Triceps           Tricep Pushdown
# 4   65bad0143ac0386d0cf7079f    Triceps           Tricep Kickback
# 5   65bad0143ac0386d0cf707a0    Triceps          Tricep Extension
# 6   65bad0143ac0386d0cf707a1       Back              Lat Pulldown
# 7   65bad0143ac0386d0cf707a2       Back        Upper Back Machine
# 8   65bad0143ac0386d0cf707a3       Back            Bent Over Rows
# 9   65bad0143ac0386d0cf707a4     Biceps           Bicep Extension
# 10  65bad0143ac0386d0cf707a5     Biceps             Biceps Hammer
# 11  65bad0143ac0386d0cf707a6     Biceps               Bicep Curls
# 12  65bad0143ac0386d0cf707a7       Legs                 Leg Press
# ...

# %%
collection2 = db.data

cursor = collection2.find({})
data = list(cursor)

# Create a DataFrame from the retrieved data
data = pd.DataFrame(data)

# %%
converter = 0.453592
multiplier = 1.899371069

def calculator (weight, repetitions):
    return ((weight/5)*16)+(repetitions-(3*(weight/5)))

# %%
data["ELO"] = data.apply(lambda x: ((calculator(x["Weight"]*converter, x["Repetitions"])) - objectives[objectives["Exercise"]==x["Exercise"]]["Actual Score"].item()) / (objectives[objectives["Exercise"]==x["Exercise"]]["Goal Score"].item() - objectives[objectives["Exercise"]==x["Exercise"]]["Actual Score"].item()) * 2400, axis=1)

# %%
data
# Out:
#                          _id                    Date Bodypart  \
# 0   65b9936ceeeb922e3c732719 2024-01-31 00:25:16.786     Back
# 1   65b99464eeeb922e3c73271e 2024-01-31 00:29:24.697     Back
# 2   65b99591eeeb922e3c732723 2024-01-31 00:34:25.965     Back
# 3   65b9964deeeb922e3c732729 2024-01-31 00:37:33.093     Back
# 4   65b99705eeeb922e3c732731 2024-01-31 00:40:37.998   Biceps
# 5   65b99855eeeb922e3c732738 2024-01-31 00:46:13.064   Biceps
# 6   65b99a0beeeb922e3c732740 2024-01-31 00:53:31.188   Biceps
# 7   65b99b82eeeb922e3c732746 2024-01-31 00:59:46.833   Biceps
# 8   65b99d1aeeeb922e3c73274e 2024-01-31 01:06:34.401     Back
# 9   65b99d21eeeb922e3c732751 2024-01-31 01:06:41.123     Back
# 10  65b99f98eeeb922e3c732759 2024-01-31 01:17:12.505     Back
# 11  65b99fa3eeeb922e3c73275e 2024-01-31 01:17:23.793     Back
# 12  65b9a007eeeb922e3c732766 2024-01-31 01:19:03.246   Biceps
# 13  65b9a095eeeb922e3c73276a 2024-01-31 01:21:25.765   Biceps
# ...

# %%
w = 92.5
r = 10
e = "Lat Pulldown"

((calculator(w*converter, r) - objectives[objectives["Exercise"]==e]["Actual Score"].item()) / (objectives[objectives["Exercise"]==e]["Goal Score"].item() - objectives[objectives["Exercise"]==e]["Actual Score"].item()) * 2400)
# Out:
# 43.18882849746608

# %%
data_to_insert = data.to_dict(orient='records')

# %%
collection2.insert_many(data_to_insert)
