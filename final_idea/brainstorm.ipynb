# %%
import pandas as pd
from pymongo import MongoClient
from datetime import datetime

# %%
x = 10
y = 15

# %%
def calculator (weight, repetitions):
    return ((weight/5)*12)+(repetitions-(2*(weight/5)))

# %%
calculator(x, y)
# Out:
# 35.0

# %%
connection_string = "mongodb+srv://marcfolchpomares:AstonMartin1@mycluster.e19nlo1.mongodb.net/?retryWrites=true&w=majority"

# Connect to MongoDB Atlas
client = MongoClient(connection_string)

# Access a specific database (replace 'your_database' with your actual database name)
db = client.ELO_gym

# Access a specific collection within the database (replace 'your_collection' with your actual collection name)
collection1 = db.data

cursor = collection1.find({})
data = list(cursor)

# Create a DataFrame from the retrieved data
objectives = pd.DataFrame(data)

collection2 = db.data

cursor = collection2.find({})
data = list(cursor)

# Create a DataFrame from the retrieved data
data = pd.DataFrame(data)

# %%
data
# Out:
#                           _id                    Date Bodypart  \
# 0    65bd6f6f07fcfab686ea4923 2024-01-31 00:25:16.786     Back
# 1    65bd6f6f07fcfab686ea4924 2024-01-31 00:29:24.697     Back
# 2    65bd6f6f07fcfab686ea4925 2024-01-31 00:34:25.965     Back
# 3    65bd6f6f07fcfab686ea4926 2024-01-31 00:37:33.093     Back
# 4    65bd6f6f07fcfab686ea4927 2024-01-31 00:40:37.998   Biceps
# ..                        ...                     ...      ...
# 169  65c584c022777a9c77864000 2024-02-09 01:49:52.043  Triceps
# 170  65c5875222777a9c7786400b 2024-02-09 02:00:50.782    Chest
# 171  65c5893222777a9c77864015 2024-02-09 02:08:50.944    Chest
# 172  65c58a8722777a9c7786401e 2024-02-09 02:14:31.827    Chest
# 173  65c69357dbe464698f8b51d4 2024-02-09 16:04:23.844     Back
#
#                  Exercise  Weight  Repetitions  Score
# 0            Lat Pulldown    77.5           16  171.0
# 1            Lat Pulldown    82.5           16  181.0
# ...

# %%
# data = data[["Date", "Bodypart", "Exercise", "Weight", "Repetitions"]]
# data["Score"] = data.apply(lambda x: calculator(x["Weight"], x["Repetitions"]), axis=1).astype(int)

# %%
data_filtered = data[data['Date'] != pd.to_datetime('today').date()]
grouped = data_filtered.groupby(["Bodypart", pd.to_datetime(data_filtered['Date']).dt.date]).agg({'Score': 'mean'}).astype(int).reset_index()
latest_index = grouped.groupby('Bodypart')['Date'].idxmax()
latest_scores = grouped.loc[latest_index]
latest_scores[latest_scores["Bodypart"]=="Back"]["Score"].item()
# Out:
# 190

# %%
import datetime as dt

# today = pd.to_datetime('today').date()
# data = data[data['Date'] < str(today)]

grouped = data.groupby(["Bodypart", pd.to_datetime(data['Date']).dt.date]).agg({'Score': 'mean'}).astype(int).reset_index()
latest_index = grouped.groupby('Bodypart')['Date'].idxmax()
latest_scores = grouped.loc[latest_index]
latest_scores

# Now, you can retrieve the latest score for "Back" excluding today's data
latest_back_score = latest_scores[latest_scores["Bodypart"] == "Back"]["Score"].item()
latest_back_score
# Out:
# 156

# %%
data
# Out:
#                       Date Bodypart              Exercise  Weight  \
# 0  2024-01-31 00:25:16.786     Back          Lat Pulldown    77.5
# 1  2024-01-31 00:29:24.697     Back          Lat Pulldown    82.5
# 2  2024-01-31 00:34:25.965     Back          Lat Pulldown    87.5
# 3  2024-01-31 00:37:33.093     Back          Lat Pulldown    92.5
# 4  2024-01-31 00:40:37.998   Biceps       Bicep Extension    15.0
# ..                     ...      ...                   ...     ...
# 75 2024-02-03 03:39:12.624     Back  Individual Cable Lat    42.5
# 76 2024-02-03 03:43:07.598   Biceps       Biceps Curl Bar    22.5
# 77 2024-02-03 03:46:58.630   Biceps       Biceps Curl Bar    27.5
# 78 2024-02-03 03:48:46.850   Biceps       Biceps Curl Bar    32.5
# 79 2024-02-03 03:51:13.856   Biceps       Biceps Curl Bar    42.5
#
#     Repetitions  Score
# 0            16    171
# 1            16    181
# 2            16    191
# 3            10    195
# 4            16     46
# ..          ...    ...
# ...

# %%
# today = pd.to_datetime('today').date()
# data = data[data['Date'] < str(today)]

last_exercise = data[(data["Bodypart"]=="Back") & (data["Exercise"]=="Lat Pulldown")]

# %%
max_date = pd.to_datetime(last_exercise['Date']).dt.date.max()

# Select all rows where the 'Date' column matches the maximum date
latest_rows = last_exercise[last_exercise['Date'].dt.date == max_date]

# Print or use the rows with the latest date as needed
latest_rows[["Date", "Weight", "Repetitions", "Score"]]
# Out:
#                       Date  Weight  Repetitions  Score
# 55 2024-02-03 02:43:49.961    77.5           16    171
# 56 2024-02-03 02:44:09.464    82.5           16    181
# 57 2024-02-03 02:44:32.423    87.5           16    191
# 58 2024-02-03 02:44:46.474    92.5           12    197

# %%
import pytz

# Set the timezone for South Carolina
sc_timezone = pytz.timezone('America/New_York')

# Get the current date and time in South Carolina
datetime.now(sc_timezone)
# Out:
# datetime.datetime(2024, 2, 3, 18, 42, 39, 277852, tzinfo=<DstTzInfo 'America/New_York' EST-1 day, 19:00:00 STD>)

# %%
# Select all rows where the 'timestamp' column matches the maximum date
latest_rows = df[df['Date'] == max_date]

# Print or use the rows with the latest date as needed
print(latest_rows)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[82], line 2
#       1 # Select all rows where the 'timestamp' column matches the maximum date
# ----> 2 latest_rows = df[df['Date'] == max_date]
#       4 # Print or use the rows with the latest date as needed
#       5 print(latest_rows)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
from pymongo import MongoClient

# Assuming you have a DataFrame named 'data'
# Replace 'your_database' and 'your_collection' with your actual database and collection names
database_name = 'ELO_gym'
collection_name = 'data'

# Connect to MongoDB
client = MongoClient('mongodb+srv://marcfolchpomares:AstonMartin1@mycluster.e19nlo1.mongodb.net/?retryWrites=true&w=majority')  # Change the connection string as needed

# Access the specified database and collection
db = client[database_name]
collection = db[collection_name]

# Drop the existing collection (delete the previous data)
collection.drop()

# Convert DataFrame to a list of dictionaries (documents)
data_list = data.to_dict(orient='records')

# Insert the new data into the collection
collection.insert_many(data_list)

# Close the MongoDB connection
client.close()

# %%
from datetime import datetime
import pytz

# Set the timezone to 'US/Eastern'
eastern = pytz.timezone('US/Eastern')

# Get the current date and time in South Carolina
current_datetime = datetime.now(eastern)

# Print the current date and time
print("Current date and time in South Carolina, USA:", current_datetime)
# Out:
# Current date and time in South Carolina, USA: 2024-02-09 16:11:13.269297-05:00

# %%
data['Date'] = data['Date'].dt.tz_localize('UTC')
data['Date'] = data['Date'].dt.tz_convert('US/Eastern')

# %%
data
# Out:
#                           _id                             Date Bodypart  \
# 0    65bd6f6f07fcfab686ea4923 2024-01-30 19:25:16.786000-05:00     Back
# 1    65bd6f6f07fcfab686ea4924 2024-01-30 19:29:24.697000-05:00     Back
# 2    65bd6f6f07fcfab686ea4925 2024-01-30 19:34:25.965000-05:00     Back
# 3    65bd6f6f07fcfab686ea4926 2024-01-30 19:37:33.093000-05:00     Back
# 4    65bd6f6f07fcfab686ea4927 2024-01-30 19:40:37.998000-05:00   Biceps
# ..                        ...                              ...      ...
# 169  65c584c022777a9c77864000 2024-02-08 20:49:52.043000-05:00  Triceps
# 170  65c5875222777a9c7786400b 2024-02-08 21:00:50.782000-05:00    Chest
# 171  65c5893222777a9c77864015 2024-02-08 21:08:50.944000-05:00    Chest
# 172  65c58a8722777a9c7786401e 2024-02-08 21:14:31.827000-05:00    Chest
# 173  65c69357dbe464698f8b51d4 2024-02-09 11:04:23.844000-05:00     Back
#
#                  Exercise  Weight  Repetitions  Score
# ...

# %%
import pymongo
from pymongo import MongoClient
import pandas as pd
from datetime import timedelta

# Connect to MongoDB
client = MongoClient("mongodb+srv://marcfolchpomares:AstonMartin1@mycluster.e19nlo1.mongodb.net/ELO_gym?retryWrites=true&w=majority")

db = client.ELO_gym

# Access a specific collection within the database (replace 'your_collection' with your actual collection name)
collection = db.data

# Get the data from the collection
cursor = collection.find({})

# Convert the cursor to a DataFrame
data = pd.DataFrame(list(cursor))

# Convert the 'Date' column to datetime if it's not already
data['Date'] = pd.to_datetime(data['Date'])

# Format the datetime column to include only date and time
data['Date'] = data['Date'].dt.strftime('%Y-%m-%d %H:%M:%S')

# Convert DataFrame to a list of dictionaries (each dictionary represents a document)
data = data.to_dict(orient='records')

# Optionally, drop the existing collection
collection.drop()

# Insert the new data into the collection
collection.insert_many(data)

print("Data replaced successfully.")
# Out:
# Data replaced successfully.

# %%
data
# Out:
# [{'_id': ObjectId('65bd6f6f07fcfab686ea4923'),
#   'Date': Timestamp('2024-01-30 19:25:16.786000-0500', tz='US/Eastern'),
#   'Bodypart': 'Back',
#   'Exercise': 'Lat Pulldown',
#   'Weight': 77.5,
#   'Repetitions': 16,
#   'Score': 171.0},
#  {'_id': ObjectId('65bd6f6f07fcfab686ea4924'),
#   'Date': Timestamp('2024-01-30 19:29:24.697000-0500', tz='US/Eastern'),
#   'Bodypart': 'Back',
#   'Exercise': 'Lat Pulldown',
#   'Weight': 82.5,
#   'Repetitions': 16,
#   'Score': 181.0},
#  {'_id': ObjectId('65bd6f6f07fcfab686ea4925'),
#   'Date': Timestamp('2024-01-30 19:34:25.965000-0500', tz='US/Eastern'),
#   'Bodypart': 'Back',
#   'Exercise': 'Lat Pulldown',
#   'Weight': 87.5,
#   'Repetitions': 16,
#   'Score': 191.0},
#  {'_id': ObjectId('65bd6f6f07fcfab686ea4926'),
#   'Date': Timestamp('2024-01-30 19:37:33.093000-0500', tz='US/Eastern'),
#   'Bodypart': 'Back',
#   'Exercise': 'Lat Pulldown',
#   'Weight': 92.5,
#   'Repetitions': 10,
#   'Score': 195.0},
# ...
